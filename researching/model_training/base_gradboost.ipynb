# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    root_mean_squared_error,
    mean_absolute_percentage_error,
)
import optuna

def smape(y_true, y_pred):
    return 100 * np.mean(2 * np.abs(y_pred - y_true) /
                         (np.abs(y_true) + np.abs(y_pred)))

df = pd.read_excel("dataset_vrp/2014-2023_lags_EWM_targets_train.xlsx")

target_col = "log_target_next_year"

exclude_cols = ["delta_target", "delta_target_percent", "target_next_year", "region", "year", "district"]

num_cols = [col for col in df.select_dtypes("number").columns if col not in (exclude_cols + [target_col])]
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

train = df[df["year"] < 2023].copy()
test = df[df["year"] == 2023].copy()

X_train = train.drop(columns=exclude_cols)
y_train = train[target_col]
X_test = test.drop(columns=exclude_cols)
y_test = test[target_col]

y_test_real = np.exp(y_test)


def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1500),
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.3),
        "max_depth": trial.suggest_int("max_depth", 2, 8),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
    }

    model = GradientBoostingRegressor(**params)
    model.fit(X_train, y_train)

    pred = model.predict(X_test)

    mae_log = mean_absolute_error(y_test, pred)
    return mae_log


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

best_params = study.best_params
print(f"Лучшие параметры: {best_params}")

model = GradientBoostingRegressor(**best_params)
model.fit(X_train, y_train)
 
pred_log = model.predict(X_test)
pred_real = np.exp(pred_log)

metrics = {
    "MAE_log": mean_absolute_error(y_test, pred_log),
    "MSE_log": mean_squared_error(y_test, pred_log),
    "R2_log": r2_score(y_test, pred_log),

    "MAE_real": mean_absolute_error(y_test_real, pred_real),
    "MSE_real": mean_squared_error(y_test_real, pred_real),
    "RMSE_real": root_mean_squared_error(y_test_real, pred_real),
    "MAPE_real": mean_absolute_percentage_error(y_test_real, pred_real),
    "SMAPE_real": smape(y_test_real, pred_real)
}

print("\nМетрики 2023:")
for name, value in metrics.items():
    print(f"{name}: {value:.4f}")
# Out:
# [I 2025-11-29 16:12:08,811] A new study created in memory with name: no-name-0acfdb5c-813e-41db-bfb0-51c3c3f02e74
# [I 2025-11-29 16:12:21,611] Trial 0 finished with value: 0.022901899210379422 and parameters: {'n_estimators': 1045, 'learning_rate': 0.17343478423182643, 'max_depth': 4, 'subsample': 0.5936678336605041, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.022901899210379422.
# [I 2025-11-29 16:12:41,011] Trial 1 finished with value: 0.009237158085447847 and parameters: {'n_estimators': 1437, 'learning_rate': 0.19830056260367146, 'max_depth': 6, 'subsample': 0.9928622985567355, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.009237158085447847.
# [I 2025-11-29 16:12:45,941] Trial 2 finished with value: 0.00994253906590763 and parameters: {'n_estimators': 320, 'learning_rate': 0.07416614191819826, 'max_depth': 4, 'subsample': 0.7393881936986288, 'min_samples_split': 19, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.009237158085447847.
# [I 2025-11-29 16:12:59,021] Trial 3 finished with value: 0.0068247879002902604 and parameters: {'n_estimators': 996, 'learning_rate': 0.010914550271379324, 'max_depth': 3, 'subsample': 0.8306458345387319, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:13:07,588] Trial 4 finished with value: 0.016808915300670937 and parameters: {'n_estimators': 1326, 'learning_rate': 0.26305803338315087, 'max_depth': 7, 'subsample': 0.5151973169632975, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:13:20,015] Trial 5 finished with value: 0.01306706842375425 and parameters: {'n_estimators': 1423, 'learning_rate': 0.2245325333286751, 'max_depth': 8, 'subsample': 0.8206860225807608, 'min_samples_split': 18, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:13:30,898] Trial 6 finished with value: 0.03631075865287574 and parameters: {'n_estimators': 1394, 'learning_rate': 0.09328255897089129, 'max_depth': 2, 'subsample': 0.7120510627777744, 'min_samples_split': 5, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:13:34,951] Trial 7 finished with value: 0.022680638222228742 and parameters: {'n_estimators': 148, 'learning_rate': 0.28870110645996583, 'max_depth': 7, 'subsample': 0.8086007340937011, 'min_samples_split': 12, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:13:46,661] Trial 8 finished with value: 0.016386417527126523 and parameters: {'n_estimators': 415, 'learning_rate': 0.09710581722932721, 'max_depth': 7, 'subsample': 0.8386873236197849, 'min_samples_split': 15, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:14:29,153] Trial 9 finished with value: 0.022983354113911236 and parameters: {'n_estimators': 1254, 'learning_rate': 0.19164982777846315, 'max_depth': 8, 'subsample': 0.9457428755619454, 'min_samples_split': 16, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:14:35,159] Trial 10 finished with value: 0.03192733733429332 and parameters: {'n_estimators': 850, 'learning_rate': 0.005119221975963321, 'max_depth': 2, 'subsample': 0.646189107517517, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:14:52,812] Trial 11 finished with value: 0.01081736179338426 and parameters: {'n_estimators': 707, 'learning_rate': 0.020295841572800566, 'max_depth': 5, 'subsample': 0.9774847416372594, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:15:16,466] Trial 12 finished with value: 0.012803376222861785 and parameters: {'n_estimators': 1044, 'learning_rate': 0.1360039398480983, 'max_depth': 5, 'subsample': 0.9051356004382173, 'min_samples_split': 5, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:15:32,220] Trial 13 finished with value: 0.032992472182227284 and parameters: {'n_estimators': 1111, 'learning_rate': 0.22110292550685717, 'max_depth': 3, 'subsample': 0.8900113730639517, 'min_samples_split': 14, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:15:55,076] Trial 14 finished with value: 0.013706241231911899 and parameters: {'n_estimators': 775, 'learning_rate': 0.13728749669655438, 'max_depth': 6, 'subsample': 0.9877416436994835, 'min_samples_split': 9, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:16:05,688] Trial 15 finished with value: 0.007751144789267528 and parameters: {'n_estimators': 570, 'learning_rate': 0.053295128378537227, 'max_depth': 4, 'subsample': 0.890458970057648, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:16:13,813] Trial 16 finished with value: 0.012250375568896498 and parameters: {'n_estimators': 559, 'learning_rate': 0.04581655426081473, 'max_depth': 3, 'subsample': 0.8653562037597097, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:16:22,046] Trial 17 finished with value: 0.011531333750640693 and parameters: {'n_estimators': 609, 'learning_rate': 0.04803399630952891, 'max_depth': 3, 'subsample': 0.7770651476142143, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:16:35,071] Trial 18 finished with value: 0.008304496718237096 and parameters: {'n_estimators': 906, 'learning_rate': 0.0386428837578369, 'max_depth': 4, 'subsample': 0.6772118393527982, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:16:41,121] Trial 19 finished with value: 0.013344397367883213 and parameters: {'n_estimators': 409, 'learning_rate': 0.07269733974350168, 'max_depth': 3, 'subsample': 0.9231609722297832, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:17:00,254] Trial 20 finished with value: 0.01498344845606513 and parameters: {'n_estimators': 1180, 'learning_rate': 0.1048276358615133, 'max_depth': 4, 'subsample': 0.7889395030561824, 'min_samples_split': 7, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:17:13,094] Trial 21 finished with value: 0.007857585881263328 and parameters: {'n_estimators': 889, 'learning_rate': 0.03829156800157131, 'max_depth': 4, 'subsample': 0.6967507364672318, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:17:26,551] Trial 22 finished with value: 0.014256417853141912 and parameters: {'n_estimators': 888, 'learning_rate': 0.005495132014080066, 'max_depth': 5, 'subsample': 0.6184723618646972, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:17:41,334] Trial 23 finished with value: 0.009502841075530332 and parameters: {'n_estimators': 979, 'learning_rate': 0.06237051357139099, 'max_depth': 4, 'subsample': 0.7202328074685578, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:17:47,461] Trial 24 finished with value: 0.009948060872685908 and parameters: {'n_estimators': 641, 'learning_rate': 0.027091980747358833, 'max_depth': 2, 'subsample': 0.8566341182779347, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:17:56,693] Trial 25 finished with value: 0.01985975334664472 and parameters: {'n_estimators': 750, 'learning_rate': 0.12434564391400407, 'max_depth': 3, 'subsample': 0.7672240069009002, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:18:01,825] Trial 26 finished with value: 0.011452039557919376 and parameters: {'n_estimators': 436, 'learning_rate': 0.06120773347229941, 'max_depth': 4, 'subsample': 0.5659488040344204, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:18:13,284] Trial 27 finished with value: 0.008516861666579443 and parameters: {'n_estimators': 551, 'learning_rate': 0.02893383602422184, 'max_depth': 6, 'subsample': 0.684863060212634, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:18:35,109] Trial 28 finished with value: 0.01031118761623111 and parameters: {'n_estimators': 982, 'learning_rate': 0.08244245824359991, 'max_depth': 5, 'subsample': 0.8675703111672344, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:18:45,217] Trial 29 finished with value: 0.025300729243201696 and parameters: {'n_estimators': 1117, 'learning_rate': 0.16236415251164346, 'max_depth': 3, 'subsample': 0.5717175712841029, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:19:04,653] Trial 30 finished with value: 0.00819249839739933 and parameters: {'n_estimators': 810, 'learning_rate': 0.1130260533096796, 'max_depth': 5, 'subsample': 0.9437321206393281, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:19:18,023] Trial 31 finished with value: 0.007623973241938952 and parameters: {'n_estimators': 695, 'learning_rate': 0.05033688372039945, 'max_depth': 4, 'subsample': 0.9241327862517129, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:19:30,519] Trial 32 finished with value: 0.00810333958687784 and parameters: {'n_estimators': 667, 'learning_rate': 0.052836234498787986, 'max_depth': 4, 'subsample': 0.8945987287854562, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:19:46,652] Trial 33 finished with value: 0.00815503665254318 and parameters: {'n_estimators': 949, 'learning_rate': 0.022974723337201637, 'max_depth': 4, 'subsample': 0.821976885942218, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:19:54,255] Trial 34 finished with value: 0.012546762286753426 and parameters: {'n_estimators': 511, 'learning_rate': 0.07898876182652936, 'max_depth': 3, 'subsample': 0.945842154213983, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:19:58,361] Trial 35 finished with value: 0.02307025574678475 and parameters: {'n_estimators': 271, 'learning_rate': 0.014546343346426929, 'max_depth': 4, 'subsample': 0.7568547786793379, 'min_samples_split': 11, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:20:04,706] Trial 36 finished with value: 0.010805313982467937 and parameters: {'n_estimators': 734, 'learning_rate': 0.033206381652883546, 'max_depth': 2, 'subsample': 0.7956326134718502, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:20:27,276] Trial 37 finished with value: 0.009984243270950644 and parameters: {'n_estimators': 1029, 'learning_rate': 0.061847285160395296, 'max_depth': 6, 'subsample': 0.7427813336393826, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:20:44,601] Trial 38 finished with value: 0.013809905857423256 and parameters: {'n_estimators': 817, 'learning_rate': 0.09008491543129554, 'max_depth': 5, 'subsample': 0.8422144728260299, 'min_samples_split': 2, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:20:47,556] Trial 39 finished with value: 0.009377223217692954 and parameters: {'n_estimators': 214, 'learning_rate': 0.047842989433810074, 'max_depth': 3, 'subsample': 0.8757591328729843, 'min_samples_split': 20, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:21:12,509] Trial 40 finished with value: 0.012535882854034829 and parameters: {'n_estimators': 1320, 'learning_rate': 0.07290257039394901, 'max_depth': 4, 'subsample': 0.9181070565578885, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.0068247879002902604.
# [I 2025-11-29 16:21:24,942] Trial 41 finished with value: 0.006695049595982238 and parameters: {'n_estimators': 670, 'learning_rate': 0.05391265141232271, 'max_depth': 4, 'subsample': 0.8949466008142863, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 41 with value: 0.006695049595982238.
# [I 2025-11-29 16:21:38,354] Trial 42 finished with value: 0.007093404918692786 and parameters: {'n_estimators': 673, 'learning_rate': 0.040303729863403054, 'max_depth': 4, 'subsample': 0.9524432808138383, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 41 with value: 0.006695049595982238.
# [I 2025-11-29 16:21:49,640] Trial 43 finished with value: 0.01223418822784192 and parameters: {'n_estimators': 478, 'learning_rate': 0.010864885523779046, 'max_depth': 5, 'subsample': 0.9659282544802401, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 41 with value: 0.006695049595982238.
# [I 2025-11-29 16:22:00,765] Trial 44 finished with value: 0.013049401279648754 and parameters: {'n_estimators': 699, 'learning_rate': 0.06129018924796145, 'max_depth': 3, 'subsample': 0.9973914845974503, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 41 with value: 0.006695049595982238.
# [I 2025-11-29 16:22:12,238] Trial 45 finished with value: 0.006537814822802332 and parameters: {'n_estimators': 599, 'learning_rate': 0.02226634360873345, 'max_depth': 4, 'subsample': 0.9290261771114127, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 45 with value: 0.006537814822802332.
# [I 2025-11-29 16:22:19,995] Trial 46 finished with value: 0.02710888790005765 and parameters: {'n_estimators': 373, 'learning_rate': 0.2801311131139569, 'max_depth': 4, 'subsample': 0.9591839797011794, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 45 with value: 0.006537814822802332.
# [I 2025-11-29 16:22:26,671] Trial 47 finished with value: 0.009002007149309198 and parameters: {'n_estimators': 617, 'learning_rate': 0.018630571648285427, 'max_depth': 2, 'subsample': 0.9231719164085063, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 45 with value: 0.006537814822802332.
# [I 2025-11-29 16:22:37,201] Trial 48 finished with value: 0.02999760621170301 and parameters: {'n_estimators': 686, 'learning_rate': 0.19455346279489863, 'max_depth': 3, 'subsample': 0.9282187902891877, 'min_samples_split': 17, 'min_samples_leaf': 2}. Best is trial 45 with value: 0.006537814822802332.
# [I 2025-11-29 16:23:10,127] Trial 49 finished with value: 0.009991929061902341 and parameters: {'n_estimators': 1485, 'learning_rate': 0.03709773987332081, 'max_depth': 5, 'subsample': 0.8342615670666551, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 45 with value: 0.006537814822802332.
# Лучшие параметры: {'n_estimators': 599, 'learning_rate': 0.02226634360873345, 'max_depth': 4, 'subsample': 0.9290261771114127, 'min_samples_split': 3, 'min_samples_leaf': 2}
#
# Метрики 2023:
# MAE_log: 0.0071
# MSE_log: 0.0004
# R2_log: 0.9997
# MAE_real: 17852.3617
# MSE_real: 14038586641.0500
# RMSE_real: 118484.5418
# MAPE_real: 0.0070
# SMAPE_real: 0.7092
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
