# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    root_mean_squared_error,
    mean_absolute_percentage_error,
)
import optuna

def smape(y_true, y_pred):
    return 100 * np.mean(2 * np.abs(y_pred - y_true) /
                         (np.abs(y_true) + np.abs(y_pred)))

df = pd.read_excel("dataset_vrp/2014-2023_lags_EWM_targets_train.xlsx")

target_col = "log_target_next_year"

exclude_cols = [
    "delta_target",
    "delta_target_percent",
    "target_next_year",
    "region",
    "district",
    "year",
]

num_cols = [col for col in df.select_dtypes("number").columns if col not in (exclude_cols + [target_col])]
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

train_df = df[df["year"] < 2023].copy()
test_df = df[df["year"] == 2023].copy()

X_train = train_df.drop(columns=exclude_cols)
y_train = train_df[target_col]
X_test = test_df.drop(columns=exclude_cols)
y_test = test_df[target_col]

cat_features = []


def objective(trial):
    params = {
        "loss_function": "MAE",
        "eval_metric": "MAE",
        "iterations": trial.suggest_int("iterations", 100, 1000),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3),
        "depth": trial.suggest_int("depth", 4, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-3, 10.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 5.0),
        "random_strength": trial.suggest_float("random_strength", 0.1, 5.0),
        "border_count": trial.suggest_int("border_count", 32, 255),
        "verbose": False,
    }

    train_pool = Pool(X_train, y_train, cat_features=cat_features)
    test_pool = Pool(X_test, y_test, cat_features=cat_features)

    model = CatBoostRegressor(**params)
    model.fit(train_pool, eval_set=test_pool, verbose=False)

    pred = model.predict(X_test)

    return mean_absolute_error(y_test, pred)


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

best_params = study.best_params
print(f"Лучшие параметры: {best_params}")

best_params["loss_function"] = "MAE"
best_params["eval_metric"] = "MAE"
best_params["verbose"] = False

model = CatBoostRegressor(**best_params)

train_pool = Pool(X_train, y_train, cat_features=cat_features)
test_pool = Pool(X_test, y_test, cat_features=cat_features)

model.fit(train_pool, eval_set=test_pool, verbose=False)

pred_log = model.predict(X_test)

y_test_real = np.exp(y_test)
pred_real = np.exp(pred_log)

metrics = {
    "MAE_log": mean_absolute_error(y_test, pred_log),
    "MSE_log": mean_squared_error(y_test, pred_log),
    "R2_log": r2_score(y_test, pred_log),
    "MAE_real": mean_absolute_error(y_test_real, pred_real),
    "MSE_real": mean_squared_error(y_test_real, pred_real),
    "RMSE_real": root_mean_squared_error(y_test_real, pred_real),
    "MAPE_real": mean_absolute_percentage_error(y_test_real, pred_real),
    "SMAPE_real": smape(y_test_real, pred_real),
}

print("\nМетрики 2023:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
# Out:
# [I 2025-11-29 16:28:17,354] A new study created in memory with name: no-name-4856de8c-4f66-4166-9153-daed2964bb1d
# [I 2025-11-29 16:28:39,185] Trial 0 finished with value: 0.12413535847621832 and parameters: {'iterations': 911, 'learning_rate': 0.05023719615498771, 'depth': 10, 'l2_leaf_reg': 7.630227902069575, 'bagging_temperature': 1.4965097110463532, 'random_strength': 2.6232142968854917, 'border_count': 70}. Best is trial 0 with value: 0.12413535847621832.
# [I 2025-11-29 16:28:39,618] Trial 1 finished with value: 0.1731119780504713 and parameters: {'iterations': 135, 'learning_rate': 0.04112427617427776, 'depth': 5, 'l2_leaf_reg': 3.002389488382696, 'bagging_temperature': 2.895335239965997, 'random_strength': 3.4225801311395676, 'border_count': 244}. Best is trial 0 with value: 0.12413535847621832.
# [I 2025-11-29 16:29:48,193] Trial 2 finished with value: 0.1629081248285871 and parameters: {'iterations': 897, 'learning_rate': 0.14160894102776717, 'depth': 10, 'l2_leaf_reg': 7.9940814722265205, 'bagging_temperature': 0.3365077360520402, 'random_strength': 4.998141917048859, 'border_count': 219}. Best is trial 0 with value: 0.12413535847621832.
# [I 2025-11-29 16:29:52,583] Trial 3 finished with value: 0.13435314846852825 and parameters: {'iterations': 479, 'learning_rate': 0.036285766321413185, 'depth': 7, 'l2_leaf_reg': 5.033128803873413, 'bagging_temperature': 4.332876985233327, 'random_strength': 3.9361874732282347, 'border_count': 246}. Best is trial 0 with value: 0.12413535847621832.
# [I 2025-11-29 16:29:53,155] Trial 4 finished with value: 0.15074506514085578 and parameters: {'iterations': 184, 'learning_rate': 0.02658137363405011, 'depth': 5, 'l2_leaf_reg': 8.962397290875185, 'bagging_temperature': 4.810132964559118, 'random_strength': 1.701857340008821, 'border_count': 198}. Best is trial 0 with value: 0.12413535847621832.
# [I 2025-11-29 16:29:53,710] Trial 5 finished with value: 0.13879542105624046 and parameters: {'iterations': 169, 'learning_rate': 0.1782794185707938, 'depth': 5, 'l2_leaf_reg': 2.7055758159754753, 'bagging_temperature': 3.840156884803843, 'random_strength': 1.9797273326021303, 'border_count': 199}. Best is trial 0 with value: 0.12413535847621832.
# [I 2025-11-29 16:29:58,669] Trial 6 finished with value: 0.28805740438419786 and parameters: {'iterations': 328, 'learning_rate': 0.006311902875338307, 'depth': 8, 'l2_leaf_reg': 8.329981304228477, 'bagging_temperature': 2.871633094329068, 'random_strength': 4.64837167973046, 'border_count': 200}. Best is trial 0 with value: 0.12413535847621832.
# [I 2025-11-29 16:29:59,807] Trial 7 finished with value: 0.09812452205173156 and parameters: {'iterations': 614, 'learning_rate': 0.11933232298186436, 'depth': 5, 'l2_leaf_reg': 0.024667359871053653, 'bagging_temperature': 2.536641742810885, 'random_strength': 1.9570762319417643, 'border_count': 104}. Best is trial 7 with value: 0.09812452205173156.
# [I 2025-11-29 16:30:02,211] Trial 8 finished with value: 0.06627240024609955 and parameters: {'iterations': 918, 'learning_rate': 0.08059652971115651, 'depth': 5, 'l2_leaf_reg': 0.858552068263548, 'bagging_temperature': 3.1211141192853638, 'random_strength': 0.22310335482462407, 'border_count': 192}. Best is trial 8 with value: 0.06627240024609955.
# [I 2025-11-29 16:30:27,816] Trial 9 finished with value: 0.17047339984140947 and parameters: {'iterations': 421, 'learning_rate': 0.19131472033541366, 'depth': 10, 'l2_leaf_reg': 5.5942268078857795, 'bagging_temperature': 1.376114345723873, 'random_strength': 2.498547482868, 'border_count': 156}. Best is trial 8 with value: 0.06627240024609955.
# [I 2025-11-29 16:30:32,689] Trial 10 finished with value: 0.14744992175952998 and parameters: {'iterations': 702, 'learning_rate': 0.2867284502172084, 'depth': 7, 'l2_leaf_reg': 0.004266530181915584, 'bagging_temperature': 3.662695386996208, 'random_strength': 0.1268557653756379, 'border_count': 144}. Best is trial 8 with value: 0.06627240024609955.
# [I 2025-11-29 16:30:33,553] Trial 11 finished with value: 0.08833076243637658 and parameters: {'iterations': 678, 'learning_rate': 0.10911251717506948, 'depth': 4, 'l2_leaf_reg': 0.4479741069724161, 'bagging_temperature': 1.9467940074413899, 'random_strength': 0.34763483276883766, 'border_count': 81}. Best is trial 8 with value: 0.06627240024609955.
# [I 2025-11-29 16:30:34,348] Trial 12 finished with value: 0.06522052422082578 and parameters: {'iterations': 769, 'learning_rate': 0.09116167944220363, 'depth': 4, 'l2_leaf_reg': 2.092344765417484, 'bagging_temperature': 1.6975383496336975, 'random_strength': 0.22813853216876692, 'border_count': 42}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:35,206] Trial 13 finished with value: 0.10241347880890207 and parameters: {'iterations': 798, 'learning_rate': 0.08845551001379616, 'depth': 4, 'l2_leaf_reg': 2.2603336091697166, 'bagging_temperature': 0.20099357357986025, 'random_strength': 0.9852359549007197, 'border_count': 42}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:37,794] Trial 14 finished with value: 0.09948877492166934 and parameters: {'iterations': 801, 'learning_rate': 0.08640066762648607, 'depth': 6, 'l2_leaf_reg': 1.5342460073725674, 'bagging_temperature': 1.8405402352264908, 'random_strength': 0.9690096104785371, 'border_count': 118}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:39,519] Trial 15 finished with value: 0.10622300327256075 and parameters: {'iterations': 986, 'learning_rate': 0.222140294712326, 'depth': 4, 'l2_leaf_reg': 3.9756042879295634, 'bagging_temperature': 1.0836268642393527, 'random_strength': 0.8504085480628327, 'border_count': 169}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:40,903] Trial 16 finished with value: 0.10981760792116116 and parameters: {'iterations': 794, 'learning_rate': 0.08795346648808514, 'depth': 6, 'l2_leaf_reg': 1.5901212950982786, 'bagging_temperature': 3.42075094378554, 'random_strength': 0.5801723606907874, 'border_count': 38}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:43,810] Trial 17 finished with value: 0.11258113486808038 and parameters: {'iterations': 903, 'learning_rate': 0.07049098293517157, 'depth': 6, 'l2_leaf_reg': 3.7900615271828713, 'bagging_temperature': 2.414846432198324, 'random_strength': 1.4610668459913967, 'border_count': 121}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:47,407] Trial 18 finished with value: 0.11090431117124372 and parameters: {'iterations': 540, 'learning_rate': 0.15287142775722076, 'depth': 8, 'l2_leaf_reg': 6.75368492713253, 'bagging_temperature': 0.8286778438951357, 'random_strength': 0.13398115267918792, 'border_count': 73}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:48,615] Trial 19 finished with value: 0.1291522042709832 and parameters: {'iterations': 736, 'learning_rate': 0.2390873205929149, 'depth': 4, 'l2_leaf_reg': 1.182255012777825, 'bagging_temperature': 3.102399994395265, 'random_strength': 1.4212294070019709, 'border_count': 159}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:55,586] Trial 20 finished with value: 0.13914857675571277 and parameters: {'iterations': 977, 'learning_rate': 0.12490166300292, 'depth': 7, 'l2_leaf_reg': 3.8041353348660123, 'bagging_temperature': 2.073455102167094, 'random_strength': 2.6247444170839076, 'border_count': 173}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:56,389] Trial 21 finished with value: 0.08631409898838392 and parameters: {'iterations': 665, 'learning_rate': 0.10508956599863473, 'depth': 4, 'l2_leaf_reg': 0.864229260129568, 'bagging_temperature': 1.941516836063371, 'random_strength': 0.4901921545734065, 'border_count': 68}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:57,083] Trial 22 finished with value: 0.09060532877021475 and parameters: {'iterations': 603, 'learning_rate': 0.06781805530607718, 'depth': 4, 'l2_leaf_reg': 1.0232178933397136, 'bagging_temperature': 2.397425382776027, 'random_strength': 0.6735228814671194, 'border_count': 52}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:58,725] Trial 23 finished with value: 0.11071804114299864 and parameters: {'iterations': 871, 'learning_rate': 0.15924294812498901, 'depth': 5, 'l2_leaf_reg': 2.0190233368952586, 'bagging_temperature': 0.7506581727588943, 'random_strength': 1.2417926516279751, 'border_count': 98}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:30:59,441] Trial 24 finished with value: 0.07018320784823256 and parameters: {'iterations': 645, 'learning_rate': 0.10297003817415919, 'depth': 4, 'l2_leaf_reg': 0.853802493702911, 'bagging_temperature': 1.6225235069884032, 'random_strength': 0.5023615248627531, 'border_count': 56}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:00,409] Trial 25 finished with value: 0.07814909648593628 and parameters: {'iterations': 752, 'learning_rate': 0.06215532275488721, 'depth': 5, 'l2_leaf_reg': 3.1447887269591814, 'bagging_temperature': 1.6430707437252652, 'random_strength': 0.1354312430387669, 'border_count': 34}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:02,666] Trial 26 finished with value: 0.08313350642921337 and parameters: {'iterations': 821, 'learning_rate': 0.13437152038413966, 'depth': 6, 'l2_leaf_reg': 2.347228876350754, 'bagging_temperature': 1.1282330185493694, 'random_strength': 1.0871351353492205, 'border_count': 91}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:03,524] Trial 27 finished with value: 0.19413105298829827 and parameters: {'iterations': 564, 'learning_rate': 0.004860972601545749, 'depth': 4, 'l2_leaf_reg': 1.8329046007459482, 'bagging_temperature': 4.115083071947729, 'random_strength': 0.48552847293957124, 'border_count': 118}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:04,144] Trial 28 finished with value: 0.114000135942713 and parameters: {'iterations': 398, 'learning_rate': 0.09601046711534678, 'depth': 5, 'l2_leaf_reg': 0.7827754824853698, 'bagging_temperature': 2.3070767130286534, 'random_strength': 3.3021667076027534, 'border_count': 54}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:14,218] Trial 29 finished with value: 0.12415570956964146 and parameters: {'iterations': 1000, 'learning_rate': 0.05521345678962549, 'depth': 9, 'l2_leaf_reg': 4.58460148174284, 'bagging_temperature': 1.474926462449012, 'random_strength': 2.4876905529983917, 'border_count': 62}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:16,855] Trial 30 finished with value: 0.1254113666499005 and parameters: {'iterations': 836, 'learning_rate': 0.1711688838993563, 'depth': 6, 'l2_leaf_reg': 9.827839246313376, 'bagging_temperature': 2.7470724051493978, 'random_strength': 0.8001471480663123, 'border_count': 134}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:17,701] Trial 31 finished with value: 0.08622661249063804 and parameters: {'iterations': 732, 'learning_rate': 0.0640589085634314, 'depth': 5, 'l2_leaf_reg': 3.0600779880419045, 'bagging_temperature': 1.3581880128027066, 'random_strength': 0.32947931621863324, 'border_count': 32}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:18,444] Trial 32 finished with value: 0.0663870932739051 and parameters: {'iterations': 637, 'learning_rate': 0.050497801865303116, 'depth': 4, 'l2_leaf_reg': 3.1331575459589454, 'bagging_temperature': 1.6765972092372439, 'random_strength': 0.209196533460212, 'border_count': 49}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:19,189] Trial 33 finished with value: 0.0780324098701513 and parameters: {'iterations': 644, 'learning_rate': 0.027652891142799285, 'depth': 4, 'l2_leaf_reg': 1.4683171102656103, 'bagging_temperature': 3.230975286009687, 'random_strength': 0.5902322451802868, 'border_count': 52}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:20,172] Trial 34 finished with value: 0.09373541888332794 and parameters: {'iterations': 513, 'learning_rate': 0.04714686601055887, 'depth': 4, 'l2_leaf_reg': 2.6619693602176393, 'bagging_temperature': 0.6762396847109382, 'random_strength': 1.3116527131584603, 'border_count': 222}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:21,683] Trial 35 finished with value: 0.07542971704514616 and parameters: {'iterations': 933, 'learning_rate': 0.1140707402960645, 'depth': 5, 'l2_leaf_reg': 3.445384427968901, 'bagging_temperature': 1.5654620633855116, 'random_strength': 0.335253772302263, 'border_count': 82}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:22,854] Trial 36 finished with value: 0.08716387807613778 and parameters: {'iterations': 598, 'learning_rate': 0.07861477091995447, 'depth': 4, 'l2_leaf_reg': 5.799759267253832, 'bagging_temperature': 2.2193578203535247, 'random_strength': 1.7207228010520432, 'border_count': 222}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:26,748] Trial 37 finished with value: 0.1015172697518378 and parameters: {'iterations': 936, 'learning_rate': 0.04245782123892715, 'depth': 5, 'l2_leaf_reg': 0.5667593159402851, 'bagging_temperature': 0.45805823518071254, 'random_strength': 3.9765861469648955, 'border_count': 238}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:29,105] Trial 38 finished with value: 0.07849734356821511 and parameters: {'iterations': 851, 'learning_rate': 0.025820154648958524, 'depth': 5, 'l2_leaf_reg': 4.536385750029933, 'bagging_temperature': 2.6322308636424543, 'random_strength': 0.790559129399588, 'border_count': 184}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:29,673] Trial 39 finished with value: 0.09905781351079944 and parameters: {'iterations': 458, 'learning_rate': 0.13854514860110007, 'depth': 4, 'l2_leaf_reg': 2.654897574650706, 'bagging_temperature': 1.7286243543117956, 'random_strength': 1.1617744760448392, 'border_count': 61}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:30,083] Trial 40 finished with value: 0.12865198062965869 and parameters: {'iterations': 270, 'learning_rate': 0.10216465461328703, 'depth': 5, 'l2_leaf_reg': 1.9676193025277091, 'bagging_temperature': 1.1206129598790096, 'random_strength': 2.137485799066278, 'border_count': 46}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:31,720] Trial 41 finished with value: 0.10048734142492564 and parameters: {'iterations': 942, 'learning_rate': 0.12545146254692113, 'depth': 5, 'l2_leaf_reg': 3.1469097941756607, 'bagging_temperature': 1.5089977280016011, 'random_strength': 0.3990017052951401, 'border_count': 81}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:32,768] Trial 42 finished with value: 0.09393592732289603 and parameters: {'iterations': 885, 'learning_rate': 0.11346609339493685, 'depth': 4, 'l2_leaf_reg': 3.6805398255855977, 'bagging_temperature': 4.752147557240722, 'random_strength': 0.27651730518940054, 'border_count': 79}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:37,508] Trial 43 finished with value: 0.08835746411342847 and parameters: {'iterations': 765, 'learning_rate': 0.07492668297136935, 'depth': 6, 'l2_leaf_reg': 1.2782687243749338, 'bagging_temperature': 3.000227860777017, 'random_strength': 0.6641122220993173, 'border_count': 255}. Best is trial 12 with value: 0.06522052422082578.
# [I 2025-11-29 16:31:38,940] Trial 44 finished with value: 0.06340638695462057 and parameters: {'iterations': 703, 'learning_rate': 0.018611599548774366, 'depth': 5, 'l2_leaf_reg': 0.30888618175116844, 'bagging_temperature': 1.238351025439891, 'random_strength': 0.13631528533275966, 'border_count': 89}. Best is trial 44 with value: 0.06340638695462057.
# [I 2025-11-29 16:31:43,646] Trial 45 finished with value: 0.0849519496528348 and parameters: {'iterations': 694, 'learning_rate': 0.019806810443540237, 'depth': 8, 'l2_leaf_reg': 0.27974319118733926, 'bagging_temperature': 2.1063307377117804, 'random_strength': 0.10427507850857115, 'border_count': 63}. Best is trial 44 with value: 0.06340638695462057.
# [I 2025-11-29 16:31:45,071] Trial 46 finished with value: 0.10347945549005855 and parameters: {'iterations': 637, 'learning_rate': 0.014001432854296614, 'depth': 4, 'l2_leaf_reg': 0.3654309652674905, 'bagging_temperature': 1.226228217866656, 'random_strength': 0.9475119471763787, 'border_count': 103}. Best is trial 44 with value: 0.06340638695462057.
# [I 2025-11-29 16:31:47,993] Trial 47 finished with value: 0.07611406261083357 and parameters: {'iterations': 708, 'learning_rate': 0.035340381020057154, 'depth': 5, 'l2_leaf_reg': 0.7484198106966341, 'bagging_temperature': 3.5689805180864376, 'random_strength': 0.5257293111145329, 'border_count': 209}. Best is trial 44 with value: 0.06340638695462057.
# [I 2025-11-29 16:31:48,699] Trial 48 finished with value: 0.06299734752991941 and parameters: {'iterations': 555, 'learning_rate': 0.050880229095714755, 'depth': 4, 'l2_leaf_reg': 2.3178497919472854, 'bagging_temperature': 1.7319506039823145, 'random_strength': 0.10708541388236552, 'border_count': 45}. Best is trial 48 with value: 0.06299734752991941.
# [I 2025-11-29 16:31:49,930] Trial 49 finished with value: 0.08047576418378356 and parameters: {'iterations': 559, 'learning_rate': 0.047878078028891796, 'depth': 6, 'l2_leaf_reg': 2.366380088831938, 'bagging_temperature': 0.8960974811480169, 'random_strength': 0.23491247677445415, 'border_count': 45}. Best is trial 48 with value: 0.06299734752991941.
# Лучшие параметры: {'iterations': 555, 'learning_rate': 0.050880229095714755, 'depth': 4, 'l2_leaf_reg': 2.3178497919472854, 'bagging_temperature': 1.7319506039823145, 'random_strength': 0.10708541388236552, 'border_count': 45}
#
# Метрики 2023:
# MAE_log: 0.0630
# MSE_log: 0.0098
# R2_log: 0.9927
# MAE_real: 81596.9731
# MSE_real: 146717196216.8564
# RMSE_real: 383036.8079
# MAPE_real: 0.0620
# SMAPE_real: 6.2745
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
