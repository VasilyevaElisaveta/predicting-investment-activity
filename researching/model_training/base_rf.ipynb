# %%
import pandas as pd
import numpy as np
import optuna
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error, mean_absolute_percentage_error
)

def smape(y_true, y_pred):
    return 100 * np.mean(2 * np.abs(y_pred - y_true) /
                         (np.abs(y_true) + np.abs(y_pred)))

df = pd.read_excel("dataset_vrp/2014-2023_lags_EWM_targets_train.xlsx")

target_col = "log_target_next_year"

exclude_cols = ["delta_target", "delta_target_percent", "target_next_year", 'year', 'region', 'district']

num_cols = [col for col in df.select_dtypes("number").columns if col not in (exclude_cols + [target_col])]
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

train = df[df["year"] < 2023]
test  = df[df["year"] == 2023]

train = train.drop(columns=exclude_cols)
test = test.drop(columns=exclude_cols)

X_train = train.drop(columns=target_col)
y_train = train[target_col]

X_test = test.drop(columns=target_col)
y_test = test[target_col]

y_test_real = np.exp(y_test)

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1500),
        "max_depth": trial.suggest_int("max_depth", 4, 15),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_float("max_features", 0.3, 1.0),
    }

    model = RandomForestRegressor(
        random_state=42,
        n_jobs=-1,
        **params
    )
    model.fit(X_train, y_train)

    pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, pred)
    return mae

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)

best_params = study.best_params
print(f"Лучшие параметры: {best_params}")

best_model = RandomForestRegressor(
    random_state=42,
    n_jobs=-1,
    **best_params
)
best_model.fit(X_train, y_train)

pred_log  = best_model.predict(X_test)
pred_real = np.exp(pred_log)

MAE_log = mean_absolute_error(y_test, pred_log)
MSE_log = mean_squared_error(y_test, pred_log)
R2_log  = r2_score(y_test, pred_log)

MAE_real = mean_absolute_error(y_test_real, pred_real)
MSE_real = mean_squared_error(y_test_real, pred_real)
RMSE_real = root_mean_squared_error(y_test_real, pred_real)
MAPE_real = mean_absolute_percentage_error(y_test_real, pred_real)
SMAPE_real = smape(y_test_real, pred_real)

metrics = {
    "MAE_log": MAE_log,
    "MSE_log": MSE_log,
    "R2_log": R2_log,

    "MAE_real": MAE_real,
    "MSE_real": MSE_real,
    "RMSE_real": RMSE_real,
    "MAPE_real": MAPE_real,
    "SMAPE_real": SMAPE_real
}

print("\nМетрики 2023:")
for name, value in metrics.items():
    print(f"{name}: {value}")
# Out:
# [I 2025-11-29 15:38:10,437] A new study created in memory with name: no-name-bdf15e14-2cc2-44e4-9435-028ca3d8fbaf
# [I 2025-11-29 15:38:11,032] Trial 0 finished with value: 0.16467379048233777 and parameters: {'n_estimators': 447, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 0.34693460565408935}. Best is trial 0 with value: 0.16467379048233777.
# [I 2025-11-29 15:38:14,389] Trial 1 finished with value: 0.13942667518173046 and parameters: {'n_estimators': 1497, 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 0.7987729770225552}. Best is trial 1 with value: 0.13942667518173046.
# [I 2025-11-29 15:38:14,716] Trial 2 finished with value: 0.14667363392612282 and parameters: {'n_estimators': 194, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 0.48914140856102983}. Best is trial 1 with value: 0.13942667518173046.
# [I 2025-11-29 15:38:16,740] Trial 3 finished with value: 0.124161170514373 and parameters: {'n_estimators': 655, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.8653765342601127}. Best is trial 3 with value: 0.124161170514373.
# [I 2025-11-29 15:38
 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8649512012994627}. Best is trial 63 with value: 0.11975440106272073.
# [I 2025-11-29 15:42:07,240] Trial 79 finished with value: 0.12291974436534649 and parameters: {'n_estimators': 1057, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.8563375963692422}. Best is trial 63 with value: 0.11975440106272073.
# [I 2025-11-29 15:42:11,939] Trial 80 finished with value: 0.12058673286180728 and parameters: {'n_estimators': 1187, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8696245929119324}. Best is trial 63 with value: 0.11975440106272073.
# [I 2025-11-29 15:42:16,677] Trial 81 finished with value: 0.11971791574156625 and parameters: {'n_estimators': 1174, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9051225392178933}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:21,450] Trial 82 finished with value: 0.12134279737204695 and parameters: {'n_estimators': 1189, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8750449298333162}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:25,701] Trial 83 finished with value: 0.12137708288838908 and parameters: {'n_estimators': 1144, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.9007019997072124}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:28,536] Trial 84 finished with value: 0.12675664473498435 and parameters: {'n_estimators': 986, 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': 0.7847917842694347}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:31,192] Trial 85 finished with value: 0.1240406749559194 and parameters: {'n_estimators': 924, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.7141951326247183}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:34,910] Trial 86 finished with value: 0.12333272032956062 and parameters: {'n_estimators': 1102, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.8711471971332738}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:39,135] Trial 87 finished with value: 0.12315309091798506 and parameters: {'n_estimators': 1221, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.8241715184139295}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:43,293] Trial 88 finished with value: 0.12300800707767366 and parameters: {'n_estimators': 1168, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.9604622106387685}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:45,583] Trial 89 finished with value: 0.13910853363768103 and parameters: {'n_estimators': 1022, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 0.9046016488276216}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:47,983] Trial 90 finished with value: 0.1256563706688916 and parameters: {'n_estimators': 881, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 0.9320068290384556}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:53,233] Trial 91 finished with value: 0.1207894932328721 and parameters: {'n_estimators': 1260, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9189889709425807}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:42:58,616] Trial 92 finished with value: 0.12103592381895124 and parameters: {'n_estimators': 1304, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.9814015608922207}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:43:04,812] Trial 93 finished with value: 0.12004679291213671 and parameters: {'n_estimators': 1454, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.949456026507666}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:43:10,598] Trial 94 finished with value: 0.12090698825088649 and parameters: {'n_estimators': 1436, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.9556477642598865}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:43:14,078] Trial 95 finished with value: 0.12051858866619591 and parameters: {'n_estimators': 825, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.9823111604583993}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:43:17,453] Trial 96 finished with value: 0.12143785869742811 and parameters: {'n_estimators': 827, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.9815061264571431}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:43:20,053] Trial 97 finished with value: 0.12321614709503206 and parameters: {'n_estimators': 684, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.9651852108397924}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:43:25,595] Trial 98 finished with value: 0.12171824821603645 and parameters: {'n_estimators': 1465, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.9339459916011433}. Best is trial 81 with value: 0.11971791574156625.
# [I 2025-11-29 15:43:27,627] Trial 99 finished with value: 0.12398570248978237 and parameters: {'n_estimators': 785, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.98454471696317}. Best is trial 81 with value: 0.11971791574156625.
# Лучшие параметры: {'n_estimators': 1174, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9051225392178933}
#
# Метрики 2023:
# MAE_log: 0.11971791574156658
# MSE_log: 0.024865667584900535
# R2_log: 0.981593872169019
# MAE_real: 66057.59006087198
# MSE_real: 62983724595.109344
# RMSE_real: 250965.5844834294
# MAPE_real: 0.12066040705899243
# SMAPE_real: 11.91538005218315
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
