# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error, root_mean_squared_error
import optuna


df = pd.read_excel("dataset_vrp/2014-2023_lags_EWM_targets_train.xlsx")

target_col = 'target_next_year'
log_target_col = 'log_target_next_year'
test_year = 2023

exclude_cols = [
    'year', 'district', 'region',
    'target_next_year', 'delta_target', 'delta_target_percent', 'log_target_next_year'
]
features = [col for col in df.columns if col not in exclude_cols]

train_df = df[df['year'] < test_year]
test_df  = df[df['year'] == test_year]

X_train = train_df[features]
y_train = train_df[target_col]

X_test = test_df[features]
y_test = test_df[target_col]


def objective(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 500, 2000),
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
        'random_seed': 42,
        'verbose': 0
    }
    model = CatBoostRegressor(**params)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    return mae 

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print(f"\nЛучшие параметры: {study.best_params}")


best_params = study.best_trial.params
best_params.update({'random_seed': 42, 'verbose': 100})
final_model = CatBoostRegressor(**best_params)
final_model.fit(X_train, y_train)

def smape(a, f):
    return 100 * np.mean(2 * np.abs(f - a) / (np.abs(a) + np.abs(f)))

y_pred = final_model.predict(X_test)

MAE_log = mean_absolute_error(test_df[log_target_col], np.log1p(y_pred))
MSE_log = mean_squared_error(test_df[log_target_col], np.log1p(y_pred))
R2_log  = r2_score(test_df[log_target_col], np.log1p(y_pred))

MAE_real = mean_absolute_error(y_test, y_pred)
MSE_real = mean_squared_error(y_test, y_pred)
RMSE_real = root_mean_squared_error(y_test, y_pred)
MAPE_real = mean_absolute_percentage_error(y_test, y_pred)
SMAPE_real = smape(y_test, y_pred)

metrics = {
    "MAE_log": MAE_log,
    "MSE_log": MSE_log,
    "R2_log": R2_log,
    "MAE_real": MAE_real,
    "MSE_real": MSE_real,
    "RMSE_real": RMSE_real,
    "MAPE_real": MAPE_real,
    "SMAPE_real": SMAPE_real
}

print(f"\nМетрики 2023:")
for name, value in metrics.items():
    print(f"{name}: {value}")
# Out:
# [I 2025-11-28 09:59:59,069] A new study created in memory with name: no-name-f8187f4e-1c46-4ed3-9603-9befa3ba8ec8
# [I 2025-11-28 10:00:16,107] Trial 0 finished with value: 82807.14444398311 and parameters: {'iterations': 1994, 'depth': 7, 'learning_rate': 0.06244046524124799, 'l2_leaf_reg': 6.515739761898409}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:00:50,665] Trial 1 finished with value: 87409.43451519596 and parameters: {'iterations': 1962, 'depth': 8, 'learning_rate': 0.19697999337254665, 'l2_leaf_reg': 6.694644434934581}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:01:00,804] Trial 2 finished with value: 86062.10394763738 and parameters: {'iterations': 795, 'depth': 7, 'learning_rate': 0.19654206972183913, 'l2_leaf_reg': 7.531423268186922}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:01:03,810] Trial 3 finished with value: 98362.20418935284 and parameters: {'iterations': 630, 'depth': 5, 'learning_rate': 0.2667226994831448, 'l2_leaf_reg': 3.4806820823228186}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:02:00,888] Trial 4 finished with value: 87684.2293399175 and parameters: {'iterations': 1324, 'depth': 9, 'learning_rate': 0.18474457692772764, 'l2_leaf_reg': 5.909887315477687}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:02:12,584] Trial 5 finished with value: 84515.79646144438 and parameters: {'iterations': 1638, 'depth': 6, 'learning_rate': 0.25289968362804705, 'l2_leaf_reg': 4.400401130521606}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:03:41,508] Trial 6 finished with value: 99792.09364295097 and parameters: {'iterations': 905, 'depth': 10, 'learning_rate': 0.24587185254658633, 'l2_leaf_reg': 3.954523871603552}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:04:49,593] Trial 7 finished with value: 84698.47736889713 and parameters: {'iterations': 1691, 'depth': 9, 'learning_rate': 0.10075126289356533, 'l2_leaf_reg': 6.030064401616001}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:05:52,168] Trial 8 finished with value: 86631.48076600899 and parameters: {'iterations': 1639, 'depth': 9, 'learning_rate': 0.028545409037931596, 'l2_leaf_reg': 4.872349186401705}. Best is trial 0 with value: 82807.14444398311.
# [I 2025-11-28 10:06:04,223] Trial 9 finished with value: 82648.21771506971 and parameters: {'iterations': 1047, 'depth': 7, 'learning_rate': 0.06388042219221093, 'l2_leaf_reg': 2.8388429100124872}. Best is trial 9 with value: 82648.21771506971.
# [I 2025-11-28 10:06:07,118] Trial 10 finished with value: 74704.58521727886 and parameters: {'iterations': 1136, 'depth': 4, 'learning_rate': 0.10577672117325018, 'l2_leaf_reg': 1.0473869598957324}. Best is trial 10 with value: 74704.58521727886.
# [I 2025-11-28 10:06:10,105] Trial 11 finished with value: 69595.50436309715 and parameters: {'iterations': 1161, 'depth': 4, 'learning_rate': 0.10870503838808522, 'l2_leaf_reg': 1.079776938260621}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:13,227] Trial 12 finished with value: 79609.66031264796 and parameters: {'iterations': 1226, 'depth': 4, 'learning_rate': 0.13504005689357765, 'l2_leaf_reg': 1.3354576290973013}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:16,510] Trial 13 finished with value: 73118.24888866594 and parameters: {'iterations': 1298, 'depth': 4, 'learning_rate': 0.1299255768128822, 'l2_leaf_reg': 9.900342603055105}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:22,103] Trial 14 finished with value: 81759.82898113523 and parameters: {'iterations': 1388, 'depth': 5, 'learning_rate': 0.14321441119095207, 'l2_leaf_reg': 9.493940539091726}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:27,901] Trial 15 finished with value: 82993.52330677136 and parameters: {'iterations': 1463, 'depth': 5, 'learning_rate': 0.09909861132450824, 'l2_leaf_reg': 9.467700271297314}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:30,269] Trial 16 finished with value: 102155.94003892699 and parameters: {'iterations': 952, 'depth': 4, 'learning_rate': 0.014557268748047733, 'l2_leaf_reg': 7.948422474824441}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:33,819] Trial 17 finished with value: 90673.9686326505 and parameters: {'iterations': 528, 'depth': 6, 'learning_rate': 0.1685666905042031, 'l2_leaf_reg': 2.4807061690436427}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:43,589] Trial 18 finished with value: 88133.6881889352 and parameters: {'iterations': 1500, 'depth': 6, 'learning_rate': 0.06616564765848088, 'l2_leaf_reg': 8.880086842340035}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:46,566] Trial 19 finished with value: 81511.08160937883 and parameters: {'iterations': 1176, 'depth': 4, 'learning_rate': 0.22229206573868796, 'l2_leaf_reg': 7.942865486838867}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:49,938] Trial 20 finished with value: 99741.10434623757 and parameters: {'iterations': 831, 'depth': 5, 'learning_rate': 0.2903817744898167, 'l2_leaf_reg': 5.0896565846445885}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:52,724] Trial 21 finished with value: 72674.86319391125 and parameters: {'iterations': 1088, 'depth': 4, 'learning_rate': 0.11513091466166785, 'l2_leaf_reg': 1.147298485946059}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:06:55,519] Trial 22 finished with value: 76943.7557977772 and parameters: {'iterations': 1069, 'depth': 4, 'learning_rate': 0.12648348460362555, 'l2_leaf_reg': 1.8530516121747214}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:07:00,857] Trial 23 finished with value: 82047.69840522482 and parameters: {'iterations': 1319, 'depth': 5, 'learning_rate': 0.11643254879380507, 'l2_leaf_reg': 2.1984157062155285}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:07:03,474] Trial 24 finished with value: 80570.45705720776 and parameters: {'iterations': 1006, 'depth': 4, 'learning_rate': 0.1551604086341558, 'l2_leaf_reg': 3.094531678128088}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:07:11,782] Trial 25 finished with value: 72737.43142291495 and parameters: {'iterations': 1237, 'depth': 6, 'learning_rate': 0.0855230368989418, 'l2_leaf_reg': 1.5458058257905734}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:07:16,662] Trial 26 finished with value: 77781.84596373739 and parameters: {'iterations': 745, 'depth': 6, 'learning_rate': 0.0820931455124592, 'l2_leaf_reg': 1.7717322000130837}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:07:21,306] Trial 27 finished with value: 77094.57949404194 and parameters: {'iterations': 1165, 'depth': 5, 'learning_rate': 0.08571192718014815, 'l2_leaf_reg': 1.0933892272918944}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:07:52,189] Trial 28 finished with value: 80290.010038936 and parameters: {'iterations': 1468, 'depth': 8, 'learning_rate': 0.04707245968708734, 'l2_leaf_reg': 2.0128190939958244}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:07:58,005] Trial 29 finished with value: 73364.4656021057 and parameters: {'iterations': 902, 'depth': 6, 'learning_rate': 0.03596421131528496, 'l2_leaf_reg': 3.451146938508209}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:08:21,303] Trial 30 finished with value: 79118.71538920014 and parameters: {'iterations': 1101, 'depth': 8, 'learning_rate': 0.0823249075636353, 'l2_leaf_reg': 1.541229283819102}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:08:24,531] Trial 31 finished with value: 76631.82337968185 and parameters: {'iterations': 1270, 'depth': 4, 'learning_rate': 0.15466044543642843, 'l2_leaf_reg': 2.7452915799290043}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:08:29,877] Trial 32 finished with value: 84035.45610851223 and parameters: {'iterations': 1376, 'depth': 5, 'learning_rate': 0.1191354584664916, 'l2_leaf_reg': 6.760057553489503}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:08:32,990] Trial 33 finished with value: 78826.12017736786 and parameters: {'iterations': 1228, 'depth': 4, 'learning_rate': 0.1389540161174943, 'l2_leaf_reg': 2.3114095414346276}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:08:39,017] Trial 34 finished with value: 74016.6634789209 and parameters: {'iterations': 1562, 'depth': 5, 'learning_rate': 0.055685439634646436, 'l2_leaf_reg': 7.179606322647226}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:08:44,149] Trial 35 finished with value: 83694.44380257065 and parameters: {'iterations': 1989, 'depth': 4, 'learning_rate': 0.17526751513455432, 'l2_leaf_reg': 1.0096477530387116}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:08:59,198] Trial 36 finished with value: 87180.27956282126 and parameters: {'iterations': 1312, 'depth': 7, 'learning_rate': 0.21348880715383003, 'l2_leaf_reg': 3.9799194398581976}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:09:05,941] Trial 37 finished with value: 82833.24559789203 and parameters: {'iterations': 1739, 'depth': 5, 'learning_rate': 0.11063176041407502, 'l2_leaf_reg': 8.595572420396305}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:09:12,396] Trial 38 finished with value: 88424.44411013101 and parameters: {'iterations': 1002, 'depth': 6, 'learning_rate': 0.0822195710334571, 'l2_leaf_reg': 9.932976204550656}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:09:51,508] Trial 39 finished with value: 82420.23633598875 and parameters: {'iterations': 1842, 'depth': 8, 'learning_rate': 0.09478945922602414, 'l2_leaf_reg': 5.708113700442234}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:12:07,444] Trial 40 finished with value: 99987.40217338642 and parameters: {'iterations': 1363, 'depth': 10, 'learning_rate': 0.15987720496009494, 'l2_leaf_reg': 1.8387436592396464}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:12:13,180] Trial 41 finished with value: 75205.44380644528 and parameters: {'iterations': 905, 'depth': 6, 'learning_rate': 0.03603034679769122, 'l2_leaf_reg': 3.4826115621378357}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:12:21,242] Trial 42 finished with value: 84825.50927804397 and parameters: {'iterations': 709, 'depth': 7, 'learning_rate': 0.06777336786037354, 'l2_leaf_reg': 3.275181572279943}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:12:26,956] Trial 43 finished with value: 71872.87449384753 and parameters: {'iterations': 881, 'depth': 6, 'learning_rate': 0.02525322163718613, 'l2_leaf_reg': 1.5060255341654385}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:12:40,524] Trial 44 finished with value: 79420.43017758775 and parameters: {'iterations': 1192, 'depth': 7, 'learning_rate': 0.18939660990267587, 'l2_leaf_reg': 1.6261791372677}. Best is trial 11 with value: 69595.50436309715.
# [I 2025-11-28 10:12:43,763] Trial 45 finished with value: 69260.93659784242 and parameters: {'iterations': 838, 'depth': 5, 'learning_rate': 0.020807864210174554, 'l2_leaf_reg': 1.3863852243367463}. Best is trial 45 with value: 69260.93659784242.
# [I 2025-11-28 10:12:46,120] Trial 46 finished with value: 72103.89655297194 and parameters: {'iterations': 594, 'depth': 5, 'learning_rate': 0.017901682126501606, 'l2_leaf_reg': 1.3952718028393583}. Best is trial 45 with value: 69260.93659784242.
# [I 2025-11-28 10:12:48,480] Trial 47 finished with value: 98663.30964278581 and parameters: {'iterations': 611, 'depth': 5, 'learning_rate': 0.0111200547681494, 'l2_leaf_reg': 2.521002663668098}. Best is trial 45 with value: 69260.93659784242.
# [I 2025-11-28 10:12:51,727] Trial 48 finished with value: 67576.93112411912 and parameters: {'iterations': 823, 'depth': 5, 'learning_rate': 0.021362268680894553, 'l2_leaf_reg': 1.3210848927268273}. Best is trial 48 with value: 67576.93112411912.
# [I 2025-11-28 10:12:54,192] Trial 49 finished with value: 75936.36011924884 and parameters: {'iterations': 637, 'depth': 5, 'learning_rate': 0.02281163917402762, 'l2_leaf_reg': 2.146327967196684}. Best is trial 48 with value: 67576.93112411912.
# Лучшие параметры: {'iterations': 823, 'depth': 5, 'learning_rate': 0.021362268680894553, 'l2_leaf_reg': 1.3210848927268273}
# 0:	learn: 531894.8251031	total: 4.57ms	remaining: 3.75s
# 100:	learn: 143038.6917304	total: 396ms	remaining: 2.83s
# 200:	learn: 67189.4583268	total: 763ms	remaining: 2.36s
# 300:	learn: 45542.6438140	total: 1.16s	remaining: 2.02s
# 400:	learn: 34319.0617100	total: 1.53s	remaining: 1.61s
# 500:	learn: 27112.9810457	total: 1.9s	remaining: 1.22s
# 600:	learn: 22305.6734227	total: 2.28s	remaining: 842ms
# 700:	learn: 19069.6078157	total: 2.66s	remaining: 463ms
# 800:	learn: 16510.5348025	total: 3.04s	remaining: 83.4ms
# 822:	learn: 16102.3552634	total: 3.12s	remaining: 0us
#
# Метрики 2023:
# MAE_log: 0.14656063282443907
# MSE_log: 0.03654136845345936
# R2_log: 0.9729512551160392
# MAE_real: 67576.93112411912
# MSE_real: 29099010296.867542
# RMSE_real: 170584.32019639888
# MAPE_real: 0.15696045947229922
# SMAPE_real: 14.55676935623697
