# %%
import pandas as pd
import numpy as np
import optuna

from sklearn.metrics import (
    mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error, mean_absolute_percentage_error
)

from xgboost import XGBRegressor

df = pd.read_excel("dataset_vrp/2014-2023_lags_EWM_targets_train.xlsx")

test_year = 2023

train_df = df[df["year"] < test_year].copy()
test_df  = df[df["year"] == test_year].copy()

target_col = "target_next_year"

exclude_cols = [
    "year", "district", "region",
    "target_next_year",
    "delta_target", "delta_target_percent",
    "log_target_next_year"
]

features = [c for c in df.columns if c not in exclude_cols]

X_train, y_train = train_df[features], train_df[target_col]
X_test,  y_test  = test_df[features],  test_df[target_col]


def objective(trial):

    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 900),
        "max_depth": trial.suggest_int("max_depth", 3, 15),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2),
        "subsample": trial.suggest_float("subsample", 0.7, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.7, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "objective": "reg:squarederror",
        "tree_method": "hist",
        "random_state": 42,
    }

    model = XGBRegressor(**params)
    model.fit(X_train, y_train)

    preds = model.predict(X_test)
    mae = mean_absolute_error(y_test, preds)

    return mae 

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)

best_params = study.best_params
print(f"\nЛучшие параметры: {best_params}")

model = XGBRegressor(
    **best_params,
    objective="reg:squarederror",
    tree_method="hist",
    random_state=42
)
model.fit(X_train, y_train)

pred_real = model.predict(X_test)

y_test_log = np.log1p(y_test)
pred_log = np.log1p(pred_real)

def smape(a, f):
    return 100 * np.mean(2 * np.abs(f - a) / (np.abs(a) + np.abs(f)))

MAE_log = mean_absolute_error(y_test_log, pred_log)
MSE_log = mean_squared_error(y_test_log, pred_log)
R2_log  = r2_score(y_test_log, pred_log)

MAE_real = mean_absolute_error(y_test, pred_real)
MSE_real = mean_squared_error(y_test, pred_real)
RMSE_real = root_mean_squared_error(y_test, pred_real)
MAPE_real = mean_absolute_percentage_error(y_test, pred_real)
SMAPE_real = smape(y_test, pred_real)


metrics = {
    "MAE_log": MAE_log,
    "MSE_log": MSE_log,
    "R2_log": R2_log,

    "MAE_real": MAE_real,
    "MSE_real": MSE_real,
    "RMSE_real": RMSE_real,
    "MAPE_real": MAPE_real,
    "SMAPE_real": SMAPE_real
}

print("\nМетрики 2023:")
for name, value in metrics.items():
    print(f"{name}: {value}")
# Out:
# [I 2025-11-28 09:43:58,696] A new study created in memory with name: no-name-14b8523c-ba1a-409f-9eaa-c0959021eeb1
# [I 2025-11-28 09:44:00,261] Trial 0 finished with value: 83601.3022147342 and parameters: {'n_estimators': 896, 'max_depth': 4, 'learning_rate': 0.07799497637802903, 'subsample': 0.769048557637041, 'colsample_bytree': 0.856046156054606, 'min_child_weight': 9}. Best is trial 0 with value: 83601.3022147342.
# [I 2025-11-28 09:44:02,585] Trial 1 finished with value: 77769.86399939658 and parameters: {'n_estimators': 533, 'max_depth': 14, 'learning_rate': 0.1768563624819698, 'subsample': 0.8650135057785586, 'colsample_bytree': 0.8386000133840602, 'min_child_weight': 8}. Best is trial 1 with value: 77769.86399939658.
# [I 2025-11-28 09:44:05,231] Trial 2 finished with value: 88636.68135369793 and parameters: {'n_estimators': 709, 'max_depth': 14, 'learning_rate': 0.15422726603236853, 'subsample': 0.8279508364454803, 'colsample_bytree': 0.7583213820886145, 'min_child_weight': 10}. Best is trial 1 with value: 77769.86399939658.
# [I 2025-11-28 09:44:07,406] Trial 3 finished with value: 72179.36846150145 and parameters: {'n_estimators': 463, 'max_depth': 15, 'learning_rate': 0.08561540523133854, 'subsample': 0.9170455192115701, 'colsample_bytree': 0.8165587445542888, 'min_child_weight': 9}. Best is trial 3 with value: 72179.36846150145.
# [I 2025-11-28 09:44:08,622] Trial 4 finished with value: 87030.8643405891 and parameters: {'n_estimators': 224, 'max_depth': 15, 'learning_rate': 0.05934594235301185, 'subsample': 0.9587929982127652, 'colsample_bytree': 0.7212756074383951, 'min_child_weight': 7}. Best is trial 3 with value: 72179.36846150145.
# [I 2025-11-28 09:44:09,998] Trial 5 finished with value: 71422.30978491381 and parameters: {'n_estimators': 543, 'max_depth': 7, 'learning_rate': 0.1700257384880386, 'subsample': 0.9530550905093498, 'colsample_bytree': 0.7737429030367502, 'min_child_weight': 6}. Best is trial 5 with value: 71422.30978491381.
# [I 2025-11-28 09:44:13,145] Trial 6 finished with value: 65977.27596491379 and parameters: {'n_estimators': 629, 'max_depth': 11, 'learning_rate': 0.13948715726791683, 'subsample': 0.8645081940825039, 'colsample_bytree': 0.9178541645423608, 'min_child_weight': 3}. Best is trial 6 with value: 65977.27596491379.
# [I 2025-11-28 09:44:14,305] Trial 7 finished with value: 98985.93148754313 and parameters: {'n_estimators': 290, 'max_depth': 12, 'learning_rate': 0.07360189497433016, 'subsample': 0.7395198721995315, 'colsample_bytree': 0.9772658680421291, 'min_child_weight': 9}. Best is trial 6 with value: 65977.27596491379.
# [I 2025-11-28 09:44:14,531] Trial 8 finished with value: 64998.87518725574 and parameters: {'n_estimators': 105, 'max_depth': 5, 'learning_rate': 0.1305940931540285, 'subsample': 0.736192161442705, 'colsample_bytree': 0.7869186503015748, 'min_child_weight': 2}. Best is trial 8 with value: 64998.87518725574.
# [I 2025-11-28 09:44:18,596] Trial 9 finished with value: 65079.69221832616 and parameters: {'n_estimators': 769, 'max_depth': 12, 'learning_rate': 0.1502913492465534, 'subsample': 0.9233325796088104, 'colsample_bytree': 0.7671490258462075, 'min_child_weight': 2}. Best is trial 8 with value: 64998.87518725574.
# [I 2025-11-28 09:44:18,790] Trial 10 finished with value: 88011.33932087643 and parameters: {'n_estimators': 115, 'max_depth': 3, 'learning_rate': 0.024161797999108017, 'subsample': 0.7005565139861267, 'colsample_bytree': 0.9023550472160305, 'min_child_weight': 4}. Best is trial 8 with value: 64998.87518725574.
# [I 2025-11-28 09:44:22,039] Trial 11 finished with value: 79007.42549113506 and parameters: {'n_estimators': 860, 'max_depth': 7, 'learning_rate': 0.12681764424768974, 'subsample': 0.8041627621179581, 'colsample_bytree': 0.7040174658384177, 'min_child_weight': 1}. Best is trial 8 with value: 64998.87518725574.
# [I 2025-11-28 09:44:24,978] Trial 12 finished with value: 82583.75271060345 and parameters: {'n_estimators': 390, 'max_depth': 9, 'learning_rate': 0.11576827520228944, 'subsample': 0.9085904933231331, 'colsample_bytree': 0.7833773090319268, 'min_child_weight': 1}. Best is trial 8 with value: 64998.87518725574.
# [I 2025-11-28 09:44:26,812] Trial 13 finished with value: 85233.78383627874 and parameters: {'n_estimators': 751, 'max_depth': 6, 'learning_rate': 0.19765847184723664, 'subsample': 0.9900239680426115, 'colsample_bytree': 0.746284460425453, 'min_child_weight': 3}. Best is trial 8 with value: 64998.87518725574.
# [I 2025-11-28 09:44:27,403] Trial 14 finished with value: 72746.2019886207 and parameters: {'n_estimators': 116, 'max_depth': 10, 'learning_rate': 0.10560293427184128, 'subsample': 0.9045237540574004, 'colsample_bytree': 0.7907976847041194, 'min_child_weight': 4}. Best is trial 8 with value: 64998.87518725574.
# [I 2025-11-28 09:44:29,330] Trial 15 finished with value: 70443.112059921 and parameters: {'n_estimators': 330, 'max_depth': 12, 'learning_rate': 0.1440712563154507, 'subsample': 0.7907163071894681, 'colsample_bytree': 0.8876714555194536, 'min_child_weight': 2}. Best is trial 8 with value: 64998.87518725574.
# [I 2025-11-28 09:44:30,865] Trial 16 finished with value: 57635.31309211567 and parameters: {'n_estimators': 720, 'max_depth': 5, 'learning_rate': 0.16977195908295403, 'subsample': 0.7062919361882393, 'colsample_bytree': 0.8248291959326344, 'min_child_weight': 5}. Best is trial 16 with value: 57635.31309211567.
# [I 2025-11-28 09:44:32,291] Trial 17 finished with value: 56939.19474019397 and parameters: {'n_estimators': 640, 'max_depth': 5, 'learning_rate': 0.1853483137029078, 'subsample': 0.702916536882104, 'colsample_bytree': 0.8636618957705576, 'min_child_weight': 5}. Best is trial 17 with value: 56939.19474019397.
# [I 2025-11-28 09:44:34,430] Trial 18 finished with value: 57032.16648130389 and parameters: {'n_estimators': 667, 'max_depth': 8, 'learning_rate': 0.19658056730864976, 'subsample': 0.7070900352719967, 'colsample_bytree': 0.9352117327444353, 'min_child_weight': 5}. Best is trial 17 with value: 56939.19474019397.
# [I 2025-11-28 09:44:36,278] Trial 19 finished with value: 71566.05591727732 and parameters: {'n_estimators': 619, 'max_depth': 8, 'learning_rate': 0.19531621376673228, 'subsample': 0.757394135220519, 'colsample_bytree': 0.9548033590911728, 'min_child_weight': 6}. Best is trial 17 with value: 56939.19474019397.
# [I 2025-11-28 09:44:38,519] Trial 20 finished with value: 64271.99002723419 and parameters: {'n_estimators': 645, 'max_depth': 8, 'learning_rate': 0.18257856237787656, 'subsample': 0.7259627821480102, 'colsample_bytree': 0.9450082402983327, 'min_child_weight': 5}. Best is trial 17 with value: 56939.19474019397.
# [I 2025-11-28 09:44:40,512] Trial 21 finished with value: 56327.898630459786 and parameters: {'n_estimators': 806, 'max_depth': 5, 'learning_rate': 0.16720925956297822, 'subsample': 0.7033857624292645, 'colsample_bytree': 0.870012605907798, 'min_child_weight': 5}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:41,964] Trial 22 finished with value: 77308.20108003594 and parameters: {'n_estimators': 817, 'max_depth': 4, 'learning_rate': 0.16336528463939515, 'subsample': 0.7005739544261627, 'colsample_bytree': 0.8695013622380903, 'min_child_weight': 7}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:43,895] Trial 23 finished with value: 61664.69474095545 and parameters: {'n_estimators': 686, 'max_depth': 6, 'learning_rate': 0.18795469378199542, 'subsample': 0.7746016729233833, 'colsample_bytree': 0.9230460553474779, 'min_child_weight': 4}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:45,074] Trial 24 finished with value: 69646.98997910204 and parameters: {'n_estimators': 808, 'max_depth': 3, 'learning_rate': 0.1601986046356517, 'subsample': 0.739041170284876, 'colsample_bytree': 0.9896955720970437, 'min_child_weight': 5}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:46,349] Trial 25 finished with value: 66827.80189810344 and parameters: {'n_estimators': 579, 'max_depth': 6, 'learning_rate': 0.19897760831598518, 'subsample': 0.7195806013986064, 'colsample_bytree': 0.8769950179085191, 'min_child_weight': 7}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:47,727] Trial 26 finished with value: 77082.74202512573 and parameters: {'n_estimators': 463, 'max_depth': 8, 'learning_rate': 0.18194711251738932, 'subsample': 0.821730560944666, 'colsample_bytree': 0.9465510161744403, 'min_child_weight': 6}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:49,155] Trial 27 finished with value: 68110.29180610631 and parameters: {'n_estimators': 679, 'max_depth': 5, 'learning_rate': 0.018751834514940904, 'subsample': 0.7552520084871224, 'colsample_bytree': 0.8959841897279935, 'min_child_weight': 4}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:50,730] Trial 28 finished with value: 62433.258411214076 and parameters: {'n_estimators': 793, 'max_depth': 4, 'learning_rate': 0.17943373260464757, 'subsample': 0.7180597258468775, 'colsample_bytree': 0.8562291136675773, 'min_child_weight': 5}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:53,229] Trial 29 finished with value: 66041.86289343394 and parameters: {'n_estimators': 591, 'max_depth': 9, 'learning_rate': 0.037645346424992066, 'subsample': 0.7768703119366503, 'colsample_bytree': 0.8575419332824187, 'min_child_weight': 3}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:55,705] Trial 30 finished with value: 84753.3239194325 and parameters: {'n_estimators': 890, 'max_depth': 7, 'learning_rate': 0.1627857549948503, 'subsample': 0.755744019539908, 'colsample_bytree': 0.9183366847748348, 'min_child_weight': 8}. Best is trial 21 with value: 56327.898630459786.
# [I 2025-11-28 09:44:57,337] Trial 31 finished with value: 53295.69724935345 and parameters: {'n_estimators': 716, 'max_depth': 5, 'learning_rate': 0.17129797787380185, 'subsample': 0.7042492728600979, 'colsample_bytree': 0.8231066254848131, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:44:58,894] Trial 32 finished with value: 96497.27823480606 and parameters: {'n_estimators': 851, 'max_depth': 4, 'learning_rate': 0.18775995848269128, 'subsample': 0.7204758393659807, 'colsample_bytree': 0.8122958782044217, 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:00,597] Trial 33 finished with value: 60575.580017492815 and parameters: {'n_estimators': 745, 'max_depth': 5, 'learning_rate': 0.17330886064502735, 'subsample': 0.7432529930608963, 'colsample_bytree': 0.8401764120926729, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:01,546] Trial 34 finished with value: 60592.72576448276 and parameters: {'n_estimators': 674, 'max_depth': 3, 'learning_rate': 0.152705476213942, 'subsample': 0.7145923956956995, 'colsample_bytree': 0.8333335654020362, 'min_child_weight': 4}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:02,748] Trial 35 finished with value: 78377.68811900863 and parameters: {'n_estimators': 539, 'max_depth': 6, 'learning_rate': 0.1327075135530944, 'subsample': 0.7942834961682752, 'colsample_bytree': 0.8047113562744306, 'min_child_weight': 7}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:04,663] Trial 36 finished with value: 71583.18200622128 and parameters: {'n_estimators': 715, 'max_depth': 7, 'learning_rate': 0.17278611124461138, 'subsample': 0.835417216855482, 'colsample_bytree': 0.8494954695149461, 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:05,698] Trial 37 finished with value: 88794.70350801725 and parameters: {'n_estimators': 499, 'max_depth': 5, 'learning_rate': 0.18956186650646603, 'subsample': 0.7334009425586286, 'colsample_bytree': 0.8844124883499799, 'min_child_weight': 8}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:08,223] Trial 38 finished with value: 53951.603808394386 and parameters: {'n_estimators': 583, 'max_depth': 10, 'learning_rate': 0.15636792334795696, 'subsample': 0.7621967313863963, 'colsample_bytree': 0.9288191525359635, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:10,822] Trial 39 finished with value: 79206.84117154097 and parameters: {'n_estimators': 604, 'max_depth': 13, 'learning_rate': 0.14393104069483953, 'subsample': 0.7644870538139911, 'colsample_bytree': 0.86705029658923, 'min_child_weight': 10}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:13,098] Trial 40 finished with value: 66593.37404447558 and parameters: {'n_estimators': 495, 'max_depth': 10, 'learning_rate': 0.08881590720224063, 'subsample': 0.7489932868299884, 'colsample_bytree': 0.9048345640667876, 'min_child_weight': 3}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:15,673] Trial 41 finished with value: 60397.682788483304 and parameters: {'n_estimators': 642, 'max_depth': 10, 'learning_rate': 0.15803226442624585, 'subsample': 0.701503221767018, 'colsample_bytree': 0.9749163069286166, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:17,962] Trial 42 finished with value: 74920.7191056753 and parameters: {'n_estimators': 570, 'max_depth': 11, 'learning_rate': 0.1700137476603989, 'subsample': 0.7284950282461594, 'colsample_bytree': 0.9611792428184874, 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45
 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:45:56,810] Trial 58 finished with value: 62953.96353522631 and parameters: {'n_estimators': 793, 'max_depth': 4, 'learning_rate': 0.1845031827887625, 'subsample': 0.7008977413665307, 'colsample_bytree': 0.9495404068909642, 'min_child_weight': 4}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:00,268] Trial 59 finished with value: 73273.85121132185 and parameters: {'n_estimators': 825, 'max_depth': 10, 'learning_rate': 0.19267035926772838, 'subsample': 0.9339590930137248, 'colsample_bytree': 0.9001653009304296, 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:01,326] Trial 60 finished with value: 70869.35643536999 and parameters: {'n_estimators': 171, 'max_depth': 13, 'learning_rate': 0.15886508621962064, 'subsample': 0.8541204156899881, 'colsample_bytree': 0.9215814787957172, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:05,014] Trial 61 finished with value: 60887.17484287716 and parameters: {'n_estimators': 734, 'max_depth': 14, 'learning_rate': 0.11097868822322082, 'subsample': 0.7096482139261666, 'colsample_bytree': 0.7952286788165783, 'min_child_weight': 4}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:09,203] Trial 62 finished with value: 63149.301304712644 and parameters: {'n_estimators': 695, 'max_depth': 15, 'learning_rate': 0.13705515254589387, 'subsample': 0.7136971360462143, 'colsample_bytree': 0.8171367591594351, 'min_child_weight': 3}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:11,795] Trial 63 finished with value: 61444.02128931394 and parameters: {'n_estimators': 558, 'max_depth': 14, 'learning_rate': 0.12575780988393087, 'subsample': 0.7233399569961914, 'colsample_bytree': 0.7840514598203696, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:13,190] Trial 64 finished with value: 58993.79341224855 and parameters: {'n_estimators': 662, 'max_depth': 6, 'learning_rate': 0.10031112462176882, 'subsample': 0.7395223866603475, 'colsample_bytree': 0.7633283975628228, 'min_child_weight': 4}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:15,780] Trial 65 finished with value: 67507.86986663076 and parameters: {'n_estimators': 721, 'max_depth': 9, 'learning_rate': 0.12781441950291197, 'subsample': 0.8867512220373028, 'colsample_bytree': 0.9990103932390741, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:19,005] Trial 66 finished with value: 57604.774628706895 and parameters: {'n_estimators': 762, 'max_depth': 11, 'learning_rate': 0.16332293704892056, 'subsample': 0.7493284248139739, 'colsample_bytree': 0.8050150245208779, 'min_child_weight': 4}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:22,466] Trial 67 finished with value: 57817.79530776581 and parameters: {'n_estimators': 894, 'max_depth': 8, 'learning_rate': 0.12313595004039198, 'subsample': 0.7097943099089639, 'colsample_bytree': 0.8604251652547368, 'min_child_weight': 2}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:24,922] Trial 68 finished with value: 78052.17708717674 and parameters: {'n_estimators': 524, 'max_depth': 15, 'learning_rate': 0.1824153154799541, 'subsample': 0.763170356301205, 'colsample_bytree': 0.8203754689169936, 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:26,790] Trial 69 finished with value: 63241.63418088004 and parameters: {'n_estimators': 608, 'max_depth': 7, 'learning_rate': 0.1187413305974309, 'subsample': 0.7194057122639745, 'colsample_bytree': 0.8059696694139666, 'min_child_weight': 3}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:28,229] Trial 70 finished with value: 71973.25325693969 and parameters: {'n_estimators': 786, 'max_depth': 5, 'learning_rate': 0.13269561747115668, 'subsample': 0.7335769025373569, 'colsample_bytree': 0.7747622306827184, 'min_child_weight': 7}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:31,308] Trial 71 finished with value: 55705.775414044554 and parameters: {'n_estimators': 674, 'max_depth': 13, 'learning_rate': 0.09573396390605432, 'subsample': 0.7041248368486507, 'colsample_bytree': 0.9411493306051152, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46:34,452] Trial 72 finished with value: 64943.2757299569 and parameters: {'n_estimators': 634, 'max_depth': 13, 'learning_rate': 0.10709959266288824, 'subsample': 0.997583290772932, 'colsample_bytree': 0.9419092890676476, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:46
 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:22,964] Trial 88 finished with value: 66353.58421060344 and parameters: {'n_estimators': 744, 'max_depth': 12, 'learning_rate': 0.11104528927008925, 'subsample': 0.7269187593027786, 'colsample_bytree': 0.9736860420054883, 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:26,934] Trial 89 finished with value: 67200.13273875718 and parameters: {'n_estimators': 868, 'max_depth': 13, 'learning_rate': 0.08159092846331661, 'subsample': 0.7361188907195113, 'colsample_bytree': 0.9171627956503445, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:30,865] Trial 90 finished with value: 57261.50956813937 and parameters: {'n_estimators': 768, 'max_depth': 15, 'learning_rate': 0.09240179877695301, 'subsample': 0.721382632533752, 'colsample_bytree': 0.9581199721634747, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:33,505] Trial 91 finished with value: 57620.030388362065 and parameters: {'n_estimators': 756, 'max_depth': 10, 'learning_rate': 0.11467574633999111, 'subsample': 0.7062456615181629, 'colsample_bytree': 0.9518349425031754, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:37,292] Trial 92 finished with value: 64927.16012749641 and parameters: {'n_estimators': 704, 'max_depth': 14, 'learning_rate': 0.16689146480463318, 'subsample': 0.7054337762921814, 'colsample_bytree': 0.9052005402799981, 'min_child_weight': 4}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:40,700] Trial 93 finished with value: 54865.7050345546 and parameters: {'n_estimators': 809, 'max_depth': 13, 'learning_rate': 0.10474244404427058, 'subsample': 0.7001223064245788, 'colsample_bytree': 0.8765009279459536, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:44,075] Trial 94 finished with value: 76445.08808133981 and parameters: {'n_estimators': 811, 'max_depth': 13, 'learning_rate': 0.10560732638224771, 'subsample': 0.7162418721131375, 'colsample_bytree': 0.9229494304955725, 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:47,388] Trial 95 finished with value: 63295.25967698118 and parameters: {'n_estimators': 781, 'max_depth': 13, 'learning_rate': 0.09862915008480931, 'subsample': 0.7265196347507401, 'colsample_bytree': 0.8762543599209693, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:51,207] Trial 96 finished with value: 66044.32068263109 and parameters: {'n_estimators': 845, 'max_depth': 12, 'learning_rate': 0.14818599886160716, 'subsample': 0.760624813366849, 'colsample_bytree': 0.9340668747151284, 'min_child_weight': 4}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:54,598] Trial 97 finished with value: 55921.02887331898 and parameters: {'n_estimators': 834, 'max_depth': 12, 'learning_rate': 0.08417043400625561, 'subsample': 0.7007096666928387, 'colsample_bytree': 0.963584505457766, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:47:58,069] Trial 98 finished with value: 59086.78125222702 and parameters: {'n_estimators': 834, 'max_depth': 12, 'learning_rate': 0.0826444538605779, 'subsample': 0.7734624629235698, 'colsample_bytree': 0.9840321383583999, 'min_child_weight': 5}. Best is trial 31 with value: 53295.69724935345.
# [I 2025-11-28 09:48:01,654] Trial 99 finished with value: 70551.93864792387 and parameters: {'n_estimators': 800, 'max_depth': 14, 'learning_rate': 0.06726136408739242, 'subsample': 0.7515842110042875, 'colsample_bytree': 0.9670208523599986, 'min_child_weight': 6}. Best is trial 31 with value: 53295.69724935345.
# Лучшие параметры: {'n_estimators': 716, 'max_depth': 5, 'learning_rate': 0.17129797787380185, 'subsample': 0.7042492728600979, 'colsample_bytree': 0.8231066254848131, 'min_child_weight': 5}
#
# Метрики 2023:
# MAE_log: 0.14847598086269756
# MSE_log: 0.0438501490810937
# R2_log: 0.9675407386900637
# MAE_real: 53295.69724935345
# MSE_real: 20228007217.75302
# RMSE_real: 142225.19895487235
# MAPE_real: 0.16445750117959476
# SMAPE_real: 14.688235656157426
