# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

import optuna

df = pd.read_excel("dataset_vrp/2014-2023_lags_EWM_targets_train.xlsx")

target_col = "target_next_year"

exclude_cols = [
    "year", "district", "region",
    "target_next_year", "delta_target", 
    "delta_target_percent", "log_target_next_year"
]

feature_cols = [c for c in df.columns if c not in exclude_cols]

train_df = df[df["year"] < 2023].copy()
test_df  = df[df["year"] == 2023].copy()

X_train = train_df[feature_cols]
y_train = train_df[target_col]

X_test = test_df[feature_cols]
y_test = test_df[target_col]


def smape(y_true, y_pred):
    return 100 * np.mean(2 * np.abs(y_pred - y_true) /
                         (np.abs(y_true) + np.abs(y_pred)))


def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 600),
        "max_depth": trial.suggest_int("max_depth", 4, 13),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical(
            "max_features", ["sqrt", "log2", 0.5, 0.7, 1.0]
        ),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False])
    }

    model = RandomForestRegressor(random_state=42, **params)
    model.fit(X_train, y_train)
    pred = model.predict(X_test)

    return mean_absolute_error(y_test, pred)


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

best_params = study.best_params
print(f"Лучшие параметры: {best_params}")


final_model = RandomForestRegressor(
    random_state=42,
    **best_params
)
final_model.fit(X_train, y_train)

pred_test = final_model.predict(X_test)

y_test_log = np.log1p(y_test)
pred_log   = np.log1p(pred_test)

MAE_log = mean_absolute_error(y_test_log, pred_log)
MSE_log = mean_squared_error(y_test_log, pred_log)
R2_log  = r2_score(y_test_log, pred_log)

# 2023 метрики
MAE_real  = mean_absolute_error(y_test, pred_test)
MSE_real  = mean_squared_error(y_test, pred_test)
RMSE_real = np.sqrt(MSE_real)
MAPE_real = mean_absolute_percentage_error(y_test, pred_test)
SMAPE_real = smape(y_test, pred_test)


metrics = {
    "MAE_log": MAE_log,
    "MSE_log": MSE_log,
    "R2_log": R2_log,

    "MAE_real": MAE_real,
    "MSE_real": MSE_real,
    "RMSE_real": RMSE_real,
    "MAPE_real": MAPE_real,
    "SMAPE_real": SMAPE_real
}

print("\nМетрики 2023:")
for name, value in metrics.items():
    print(f"{name}: {value:.2f}")
# Out:
# [I 2025-11-28 09:16:48,074] A new study created in memory with name: no-name-84216093-03ac-4a48-a854-8f4a0b11f2bc
# [I 2025-11-28 09:16:48,508] Trial 0 finished with value: 136879.2051273537 and parameters: {'n_estimators': 136, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 136879.2051273537.
# [I 2025-11-28 09:16:52,785] Trial 1 finished with value: 97305.13512362762 and parameters: {'n_estimators': 308, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 0.7, 'bootstrap': True}. Best is trial 1 with value: 97305.13512362762.
# [I 2025-11-28 09:16:53,110] Trial 2 finished with value: 137257.074101282 and parameters: {'n_estimators': 110, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 1 with value: 97305.13512362762.
# [I 2025-11-28 09:16:56,842] Trial 3 finished with value: 78769.0634722166 and parameters: {'n_estimators': 395, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:16:58,123] Trial 4 finished with value: 147897.62030672218 and parameters: {'n_estimators': 424, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:16:59,921] Trial 5 finished with value: 145373.95292324972 and parameters: {'n_estimators': 590, 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:17:04,196] Trial 6 finished with value: 122742.59393373012 and parameters: {'n_estimators': 413, 'max_depth': 12, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': 0.5, 'bootstrap': True}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:17:06,770] Trial 7 finished with value: 100464.06232344142 and parameters: {'n_estimators': 495, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:17:11,377] Trial 8 finished with value: 87160.83087462885 and parameters: {'n_estimators': 367, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 0.7, 'bootstrap': True}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:17:16,365] Trial 9 finished with value: 109238.74249894508 and parameters: {'n_estimators': 553, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 0.5, 'bootstrap': True}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:17:22,054] Trial 10 finished with value: 139363.08110518908 and parameters: {'n_estimators': 283, 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 1, 'max_features': 1.0, 'bootstrap': False}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:17:26,086] Trial 11 finished with value: 80092.46625935947 and parameters: {'n_estimators': 263, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.7, 'bootstrap': True}. Best is trial 3 with value: 78769.0634722166.
# [I 2025-11-28 09:17:29,953] Trial 12 finished with value: 69371.07475081898 and parameters: {'n_estimators': 226, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:17:33,583] Trial 13 finished with value: 72659.54202902186 and parameters: {'n_estimators': 212, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:17:36,849] Trial 14 finished with value: 76000.34724668723 and parameters: {'n_estimators': 186, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 0.7, 'bootstrap': True}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:17:37,370] Trial 15 finished with value: 119604.5500229733 and parameters: {'n_estimators': 214, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:17:42,746] Trial 16 finished with value: 69705.89499979136 and parameters: {'n_estimators': 225, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': True}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:17:46,799] Trial 17 finished with value: 74436.9586957198 and parameters: {'n_estimators': 166, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 1.0, 'bootstrap': True}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:17:58,698] Trial 18 finished with value: 96987.67623388863 and parameters: {'n_estimators': 326, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:18:04,602] Trial 19 finished with value: 79339.19668205944 and parameters: {'n_estimators': 246, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:18:07,596] Trial 20 finished with value: 75165.71531088062 and parameters: {'n_estimators': 149, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': True}. Best is trial 12 with value: 69371.07475081898.
# [I 2025-11-28 09:18:11,331] Trial 21 finished with value: 68463.62049903571 and parameters: {'n_estimators': 216, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:15,428] Trial 22 finished with value: 69310.10641345044 and parameters: {'n_estimators': 237, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:20,057] Trial 23 finished with value: 70540.71648171294 and parameters: {'n_estimators': 286, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:23,283] Trial 24 finished with value: 83328.69030830149 and parameters: {'n_estimators': 194, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:27,033] Trial 25 finished with value: 70236.60631029877 and parameters: {'n_estimators': 252, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:30,009] Trial 26 finished with value: 78065.7064533939 and parameters: {'n_estimators': 102, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.7, 'bootstrap': False}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:35,638] Trial 27 finished with value: 78116.9456362612 and parameters: {'n_estimators': 336, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:36,065] Trial 28 finished with value: 134143.0779551736 and parameters: {'n_estimators': 171, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:37,650] Trial 29 finished with value: 70151.28731751296 and parameters: {'n_estimators': 131, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.5, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:43,405] Trial 30 finished with value: 91602.81412381657 and parameters: {'n_estimators': 368, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:48,730] Trial 31 finished with value: 71742.30630846364 and parameters: {'n_estimators': 224, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:53,798] Trial 32 finished with value: 73556.76193100029 and parameters: {'n_estimators': 298, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:54,466] Trial 33 finished with value: 109392.55383306788 and parameters: {'n_estimators': 236, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:18:58,748] Trial 34 finished with value: 73519.97725820863 and parameters: {'n_estimators': 271, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:01,941] Trial 35 finished with value: 75417.02899070445 and parameters: {'n_estimators': 134, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 1.0, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:03,044] Trial 36 finished with value: 112061.22594837494 and parameters: {'n_estimators': 319, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:05,601] Trial 37 finished with value: 69186.92514377918 and parameters: {'n_estimators': 195, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:08,217] Trial 38 finished with value: 72385.96289059945 and parameters: {'n_estimators': 200, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:16,069] Trial 39 finished with value: 84203.83957054083 and parameters: {'n_estimators': 454, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 0.7, 'bootstrap': False}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:16,556] Trial 40 finished with value: 123296.85108322559 and parameters: {'n_estimators': 174, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:20,835] Trial 41 finished with value: 71667.84007661039 and parameters: {'n_estimators': 237, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:22,446] Trial 42 finished with value: 108818.1416456466 and parameters: {'n_estimators': 153, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 0.5, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:24,817] Trial 43 finished with value: 72651.4642438363 and parameters: {'n_estimators': 213, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:26,940] Trial 44 finished with value: 72657.76593514749 and parameters: {'n_estimators': 122, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:27,663] Trial 45 finished with value: 161700.67139090746 and parameters: {'n_estimators': 263, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:32,693] Trial 46 finished with value: 103340.98600523546 and parameters: {'n_estimators': 305, 'max_depth': 13, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:33,988] Trial 47 finished with value: 81254.28394357343 and parameters: {'n_estimators': 188, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 0.5, 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:40,264] Trial 48 finished with value: 108195.99347565736 and parameters: {'n_estimators': 220, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': False}. Best is trial 21 with value: 68463.62049903571.
# [I 2025-11-28 09:19:40,964] Trial 49 finished with value: 120447.52520865333 and parameters: {'n_estimators': 280, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True}. Best is trial 21 with value: 68463.62049903571.
# Лучшие параметры: {'n_estimators': 216, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 0.7, 'bootstrap': True}
#
# Метрики 2023:
# MAE_log: 0.12
# MSE_log: 0.03
# R2_log: 0.98
# MAE_real: 68463.62
# MSE_real: 90063669566.07
# RMSE_real: 300106.10
# MAPE_real: 0.13
# SMAPE_real: 12.31
